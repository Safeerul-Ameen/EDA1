# %%
# Import all neccessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing DATASET
df=pd.read_csv('Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# * **LB: Likely stands for "Baseline Fetal Heart Rate (FHR)**
# * **AC: Could represent "Accelerations" in the FHR**
# * **FM: May indicate "Fetal Movements" detected by the monitor**
# * **UC: Likely denotes "Uterine Contractions**
# * **DL: Could stand for "Decelerations Late**
# * **DS: May represent "Decelerations Short**
# * **DP: Could indicate "Decelerations Prolonged**
# * **ASTV: Might refer to "Percentage of Time with Abnormal Short Term Variability**
# * **MSTV: Likely stands for "Mean Value of Short Term Variability**
# * **ALTV: Could represent "Percentage of Time with Abnormal Long Term Variability**
# * **MLTV: Might indicate "Mean Value of Long Term Variability**
# * **Width: Likely an additional metric related to the FHR or uterine activity**
# * **Tendency: Potentially indicates the trend or pattern in the data**
# * **NSP: Non-Stress Test results or outcome indicator**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# **All columns were initially of type float64**

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# ## Data Cleaning
# ### 1 Handling Missing Values

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Check the proportion of missing values in each column
missing_values = df.isnull().mean() * 100
missing_values.sort_values(ascending=False)
# Out:
# LB          0.987770
# DS          0.987770
# DP          0.987770
# MLTV        0.987770
# Width       0.987770
# Tendency    0.987770
# NSP         0.987770
# AC          0.940734
# FM          0.000000
# UC          0.000000
# DL          0.000000
# ASTV        0.000000
# MSTV        0.000000
# ALTV        0.000000
# dtype: float64

# %% [markdown]
# **The dataset has missing values in several columns, but the proportion is relatively small (about 0.99% to 0.94%) for those affected**
# * LB, DS, DP, MLTV, Width, Tendency, NSP: ~0.99% missing
# * AC: ~0.94% missing

# %%
# Impute missing values with the median of each column
df_imputed = df.fillna(df.median())

# Verify that there are no more missing values
missing_values_after_imputation = df_imputed.isnull().sum()

missing_values_after_imputation
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# ### 2 Handling Outliers

# %%
# Set up the matplotlib figure
plt.figure(figsize=(16, 10))

# Generate boxplots for each column
df_imputed.boxplot(grid=False, rot=45, fontsize=10)

# Display the plot
plt.title('Boxplots of Numerical Variables')
plt.show()

# %%
## visualisatoion of outliers by boxplot
col_nam=list(df_imputed.columns)
fig=plt.figure(figsize=(20,10))
for i in col_nam:
    df.boxplot(column=i,grid=True,
    patch_artist=True,
    boxprops=dict(color='blue', facecolor='lightblue'),
    whiskerprops=dict(color='green', linewidth=2),
    medianprops=dict(color='orange', linewidth=2),
    flierprops=dict(marker='o', color='purple', markersize=5),
    notch=True,
    vert=False)
    plt.show()

# %%
# percentage of outlier for each column
column=list(df_imputed.columns)
for i in column:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df_imputed[i].quantile(0.25)
    Q3 = df_imputed[i].quantile(0.75)

    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1

    # Determine the lower and upper limits
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df_imputed[(df_imputed[i] < lower_limit) | (df_imputed[i] > upper_limit)]

    # Calculate the percentage of outliers
    percentage_outliers = (len(outliers) / len(df_imputed)) * 100

    print(f"Percentage of outliers in {i}: {percentage_outliers:.2f}%")
# Out:
# Percentage of outliers in LB: 0.47%
# Percentage of outliers in AC: 2.02%
# Percentage of outliers in FM: 16.32%
# Percentage of outliers in UC: 0.61%
# Percentage of outliers in DL: 5.88%
# Percentage of outliers in DS: 5.64%
# Percentage of outliers in DP: 13.36%
# Percentage of outliers in ASTV: 0.47%
# Percentage of outliers in MSTV: 3.76%
# Percentage of outliers in ALTV: 14.96%
# Percentage of outliers in MLTV: 3.81%
# Percentage of outliers in Width: 0.47%
# Percentage of outliers in Tendency: 0.47%
# Percentage of outliers in NSP: 26.29%

# %% [markdown]
# * These percentages indicate that certain columns have a higher concentration of outliers than others, especially:
# * FM (16.32%) ,DP (13.36%), ALTV (14.96%), NSP (26.29%)

# %%
# Impute outliers with the median for low % outliers. 
#col = ['LB','AC','UC','DL','DS','ASTV','MSTV','MLTV','Width','Tendency']
#for i in col:
#    df_imputed[i] = np.where(df_imputed[i] > upper_limit, df_imputed[i].median(), 
#                            np.where(df_imputed[i] < lower_limit, df_imputed[i].median(), df_imputed[i]))

# %% [markdown]
# ### Statistical summary

# %%
# Calculate statistical summary for each column in the dataset
summary_stats = df_imputed.describe().T

# Calculate additional measures: IQR and median
summary_stats['IQR'] = summary_stats['75%'] - summary_stats['25%']
summary_stats['median'] = df_imputed.median()

# Select only relevant columns: mean, median, std, IQR
summary_stats = summary_stats[['mean', 'median', 'std', 'IQR']]

# Display the summary
print(summary_stats)
# Out:
#                 mean      median        std        IQR
# LB        133.340204  133.000000  11.214379  14.000000
# AC          0.003204    0.001634   0.004373   0.005606
# FM          0.009894    0.000000   0.067540   0.002567
# UC          0.004391    0.004484   0.003340   0.004685
# DL          0.001895    0.000000   0.003343   0.003289
# DS          0.000002    0.000000   0.000141   0.000000
# DP          0.000173    0.000000   0.000836   0.000000
# ASTV       46.995984   49.000000  18.813973  29.000000
# MSTV        1.364378    1.200000   1.173632   1.000000
# ALTV       10.285964    0.000000  21.205041  11.000000
# MLTV        8.276147    7.400000   7.734851   6.200000
# Width      70.395387   67.000000  42.720508  63.000000
# Tendency    0.313246    0.000000   0.643186   1.000000
# NSP         1.301499    1.000000   0.642133   0.000000

# %% [markdown]
# Skewness: If the mean is significantly higher or lower than the median, it suggests that the data is skewed.
#   * ALTV has positive skewnness. also it has high IQR which means data is more spread out, which could mean more variability in the measurements

# %% [markdown]
# ### Histogram

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")
# Set up the figure for histograms
plt.figure(figsize=(16, 20))
for i, column in enumerate(df_imputed.columns, 1):
    plt.subplot(len(df_imputed.columns)//3 + 1, 3, i)
    sns.histplot(df_imputed[column], bins=20, kde=True)
    plt.title(f'Histogram of {column}')
plt.tight_layout()
plt.show();

# %%
# Set up the figure for boxplots
plt.figure(figsize=(16, 20))
for i, column in enumerate(df_imputed.columns, 1):
    plt.subplot(len(df_imputed.columns)//3 + 1, 3, i)
    sns.boxplot(df_imputed[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df_imputed.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Pair plot to show relationships between variables
sns.pairplot(df_imputed)
plt.show()

# %%
sns.scatterplot(data=df_imputed)
# Out:
# <Axes: >

# %% [markdown]
# Summary
# * DL, MSTV,Width are in around 0.5 correlation.
# * ALTV,ASTV,NSP are in around 0.5 correlation.
# * FM (16.32%) ,DP (13.36%), ALTV (14.96%), NSP (26.29%) These fields have significant outliers percentages. Need to consider consider this while do analysis.
